# %% [markdown]
# ## # Preface

# %% [markdown]
# ### Why python?

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Og847HVwRSI')

# %% [markdown]
# - 오픈 소스
# - 간단한(짧은) 코드 / 쉬운 문법
# - 방대한 library
# - I think...구글에서 ML 언어로 채택

# %% [markdown]
# ### IDE(Integrated Development Environment)

# %% [markdown]
# - 메모장에서도 python 코드 작성은 가능 -> 예시 <br>
# 하지만... -> IDE가 개발된 이유
# - python : pycharm, jupyter notebook

# %% [markdown]
# ### Jupyter notebook 사용법

# %% [markdown]
# - green : 편집 가능 상태
# - blue : 단축키 적용 가능 상태

# %% [markdown]
# - markdown cell : m
# - programming cell : y

# %% [markdown]
# - shift / ctrl / alt + enter

# %% [markdown]
# - 단축키 <br>
# a : above cell 추가 <br>
# b : below cell 추가 <br>
# x : cell 삭제 <br>
# h : help

# %% [markdown]
# # # 연습
# ## ## 연습
# ### ### 연습
# - 연습

# %% [markdown]
# ## Print

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print('"Hello, world!"')
# Out:
# "Hello, world!"

# %%
print("'Hello, world!'")
# Out:
# 'Hello, world!'

# %%
print('cat', 'dog', 'mice')
# Out:
# cat dog mice

# %%
print('cat', 'dog', 'mice', sep = ',')
# Out:
# cat,dog,mice

# %%
print('cat', 'dog', 'mice', sep = ', ')
# Out:
# cat, dog, mice

# %%
print('cat,', 'dog,', 'mice')
# Out:
# cat, dog, mice

# %%
print('cat, dog, mice')
# Out:
# cat, dog, mice

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello', end = '')
print('world')
# Out:
# helloworld

# %%
print('hello', end = ' ')
print('world')
# Out:
# hello world

# %%
print(2==2)
# Out:
# True

# %%
print('2 == 3 ?', 2==3)
# Out:
# 2 == 3 ? False

# %% [markdown]
# ## 주석 처리

# %% [markdown]
# #### # : line 주석 처리
# #### ''' ''' : 장문 주석 처리

# %%
print('Hello, world!')
print('Hello, world!!')
print('Hello, world!!!')
print('Hello, world!!!!')
# Out:
# Hello, world!
# Hello, world!!

# %%
print('Hello, world!')
# print('Hello, world!!')
print('Hello, world!!!')
# print('Hello, world!!!!')
# Out:
# Hello, world!
# Hello, world!!!

# %%
print('Hello, world!')
'''print('Hello, world!!')
    print('Hello, world!!!')
    print('Hello, world!!!!')'''
# Out:
# Hello, world!
# "print('Hello, world!!')\n    print('Hello, world!!!')\n    print('Hello, world!!!!')"

# %% [markdown]
# - 주석은 원래 출력되지 않음
# - pycharm 예시

# %% [markdown]
# ### Remark

# %% [markdown]
# https://github.com/foryou802/cell_python_basic
